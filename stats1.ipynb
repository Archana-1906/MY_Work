# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("sales_data_with_discounts.csv")
df
# Out:
#            Date       Day  SKU City  Volume         BU  Brand       Model  \
# 0    01-04-2021  Thursday  M01    C      15    Mobiles  RealU       RU-10
# 1    01-04-2021  Thursday  M02    C      10    Mobiles  RealU   RU-9 Plus
# 2    01-04-2021  Thursday  M03    C       7    Mobiles   YouM       YM-99
# 3    01-04-2021  Thursday  M04    C       6    Mobiles   YouM  YM-99 Plus
# 4    01-04-2021  Thursday  M05    C       3    Mobiles   YouM      YM-98
# ..          ...       ...  ...  ...     ...        ...    ...         ...
# 445  15-04-2021  Thursday  L06    C       2  Lifestyle  Jeera   M-Casuals
# 446  15-04-2021  Thursday  L07    C       6  Lifestyle   Viva   W-Western
# 447  15-04-2021  Thursday  L08    C       2  Lifestyle   Viva    W-Lounge
# 448  15-04-2021  Thursday  L09    C       3  Lifestyle  Jeera   M-Formals
# 449  15-04-2021  Thursday  L10    C       1  Lifestyle  Jeera     M-Shoes
#
#      Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# ...

# %%
df.head()
# Out:
#          Date       Day  SKU City  Volume       BU  Brand       Model  \
# 0  01-04-2021  Thursday  M01    C      15  Mobiles  RealU       RU-10
# 1  01-04-2021  Thursday  M02    C      10  Mobiles  RealU   RU-9 Plus
# 2  01-04-2021  Thursday  M03    C       7  Mobiles   YouM       YM-99
# 3  01-04-2021  Thursday  M04    C       6  Mobiles   YouM  YM-99 Plus
# 4  01-04-2021  Thursday  M05    C       3  Mobiles   YouM      YM-98
#
#    Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0      12100             181500          11.654820     21153.498820
# 1      10100             101000          11.560498     11676.102960
# 2      16100             112700           9.456886     10657.910160
# 3      20100             120600           6.935385      8364.074702
# 4       8100              24300          17.995663      4372.946230
#
#    Net Sales Value
# 0     160346.50120
# 1      89323.89704
# 2     102042.08980
# 3     112235.92530
# 4      19927.05377

# %%
df.describe() #describe() calculates the statistical information of numerical columns
# Out:
#            Volume     Avg Price  Total Sales Value  Discount Rate (%)  \
# count  450.000000    450.000000         450.000000         450.000000
# mean     5.066667  10453.433333       33812.835556          15.155242
# std      4.231602  18079.904840       50535.074173           4.220602
# min      1.000000    290.000000         400.000000           5.007822
# 25%      3.000000    465.000000        2700.000000          13.965063
# 50%      4.000000   1450.000000        5700.000000          16.577766
# 75%      6.000000  10100.000000       53200.000000          18.114718
# max     31.000000  60100.000000      196400.000000          19.992407
#
#        Discount Amount  Net Sales Value
# count       450.000000       450.000000
# mean       3346.499424     30466.336131
# std        4509.902963     46358.656624
# min          69.177942       326.974801
# 25%         460.459304      2202.208645
# 50%         988.933733      4677.788059
# 75%        5316.495426     47847.912855
# ...

# %%
 #Histogram for each numerical column

df.hist()
plt.tight_layout()

# %%
df.boxplot(figsize=(15,5))
plt.tight_layout()

# %%
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x269482ec050>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x269482ec620>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x269482c7d40>],
#  'medians': [<matplotlib.lines.Line2D at 0x269482ecad0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x269482ecd70>],
#  'means': []}

# %%
df.dtypes
# Out:
# Date                  object
# Day                   object
# SKU                   object
# City                  object
# Volume                 int64
# BU                    object
# Brand                 object
# Model                 object
# Avg Price              int64
# Total Sales Value      int64
# Discount Rate (%)    float64
# Discount Amount      float64
# Net Sales Value      float64
# dtype: object

# %%
df.value_counts()
# Out:
# Date        Day       SKU  City  Volume  BU       Brand    Model        Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  Net Sales Value
# 01-04-2021  Thursday  F01  C     13      FMCG     Babaji   Babaji Oil   400        5200               18.869242          981.200566       4218.799434        1
# 12-04-2021  Monday    F08  C     3       FMCG     Gear     Gear Cream   400        1200               15.770607          189.247288       1010.752712        1
# 11-04-2021  Sunday    F08  C     2       FMCG     Gear     Gear Cream   400        800                19.992407          159.939256       640.060744         1
#                       F07  C     4       FMCG     Gear     Gear Oil     500        2000               17.124515          342.490303       1657.509697        1
#                       F06  C     2       FMCG     Vedic    Vedic Oil    450        900                18.484266          166.358397       733.641603         1
# ...

# %%
#categorical column in dataset
categorical_col=df.select_dtypes(include=['object','category']).columns
print(categorical_col)
# Out:
# Index(['Date', 'Day', 'SKU', 'City', 'BU', 'Brand', 'Model'], dtype='object')

# %%
#Plotting Bar charts for all the categoricl column

df['Date'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Date'>

# %%
df['Day'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Day'>

# %%
df['SKU'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='SKU'>

# %%
df['City'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='City'>

# %%
df['BU'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='BU'>

# %%
df['Brand'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Brand'>

# %%
df['Model'].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='Model'>

# %%
#Standardize the data
from sklearn.preprocessing import StandardScaler

# %%
sc=StandardScaler()

# %%
sc.fit_transform(df)
# Out:
# array([[ 2.35002911,  0.091173  ,  2.92572115, ..., -0.18569534,
#         -0.18569534, -0.18569534],
#        [ 1.16712855, -0.01957016,  1.33099521, ..., -0.18569534,
#         -0.18569534, -0.18569534],
#        [ 0.45738822,  0.31265934,  1.56277525, ..., -0.18569534,
#          5.38516481, -0.18569534],
#        ...,
#        [-0.72551234, -0.49022863, -0.60644824, ..., -0.18569534,
#         -0.18569534, -0.18569534],
#        [-0.48893223, -0.47361715, -0.55692259, ..., -0.18569534,
#         -0.18569534, -0.18569534],
#        [-0.96209245, -0.40717125, -0.60842926, ..., -0.18569534,
#         -0.18569534, -0.18569534]])

# %%
df.head()
# Out:
#    Volume  Avg Price  Total Sales Value  Discount Rate (%)  Discount Amount  \
# 0      15      12100             181500          11.654820     21153.498820
# 1      10      10100             101000          11.560498     11676.102960
# 2       7      16100             112700           9.456886     10657.910160
# 3       6      20100             120600           6.935385      8364.074702
# 4       3       8100              24300          17.995663      4372.946230
#
#    Net Sales Value  Date_01-04-2021  Date_02-04-2021  Date_03-04-2021  \
# 0     160346.50120             True            False            False
# 1      89323.89704             True            False            False
# 2     102042.08980             True            False            False
# 3     112235.92530             True            False            False
# 4      19927.05377             True            False            False
#
#    Date_04-04-2021  ...  Model_Vedic Cream  Model_Vedic Oil  \
# ...

# %%
df=pd.get_dummies(data=df,columns=['Brand'])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df=pd.get_dummies(data=df,columns=['Brand'])
#
# NameError: name 'df' is not defined
