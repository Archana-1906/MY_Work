# %%
import  pandas as pd

# %%
#1.Load the dataset into a DataFrameor equivalent data structure
data=pd.read_csv("Cardiotocographic.csv")

# %%
data.head()
# Out:
#            LB        AC   FM        UC        DL   DS   DP  ASTV  MSTV  ALTV  \
# 0  120.000000  0.000000  0.0  0.000000  0.000000  0.0  0.0  73.0   0.5  43.0
# 1  132.000000  0.006380  0.0  0.006380  0.003190  0.0  0.0  17.0   2.1   0.0
# 2  133.000000  0.003322  0.0  0.008306  0.003322  0.0  0.0  16.0   2.1   0.0
# 3  134.000000  0.002561  0.0  0.007742  0.002561  0.0  0.0  16.0   2.4   0.0
# 4  131.948232  0.006515  0.0  0.008143  0.000000  0.0  0.0  16.0   2.4   0.0
#
#    MLTV  Width  Tendency  NSP
# 0   2.4   64.0  0.999926  2.0
# 1  10.4  130.0  0.000000  1.0
# 2  13.4  130.0  0.000000  1.0
# 3  23.0  117.0  1.000000  1.0
# 4  19.9  117.0  1.000000  1.0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2126 entries, 0 to 2125
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   LB        2105 non-null   float64
#  1   AC        2106 non-null   float64
#  2   FM        2126 non-null   float64
#  3   UC        2126 non-null   float64
#  4   DL        2126 non-null   float64
#  5   DS        2105 non-null   float64
#  6   DP        2105 non-null   float64
#  7   ASTV      2126 non-null   float64
#  8   MSTV      2126 non-null   float64
#  9   ALTV      2126 non-null   float64
#  10  MLTV      2105 non-null   float64
#  11  Width     2105 non-null   float64
#  12  Tendency  2105 non-null   float64
#  13  NSP       2105 non-null   float64
# dtypes: float64(14)
# memory usage: 232.7 KB

# %%
data.shape
# Out:
# (2126, 14)

# %%
data.isnull().sum() #display no. of  null values in each column
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
data.dtypes
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %%
data.duplicated() #display duplicated rows with booolean type True and all
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2121    False
# 2122    False
# 2123    False
# 2124    False
# 2125    False
# Length: 2126, dtype: bool

# %%
data[data.duplicated()]
# Out:
#          LB        AC   FM        UC   DL   DS   DP  ASTV  MSTV  ALTV  MLTV  \
# 1115  122.0  0.000000  0.0  0.000000  0.0  0.0  0.0  19.0   1.9   0.0  15.1
# 1458  148.0  0.004717  0.0  0.002358  0.0  0.0  0.0  40.0   0.9   0.0  10.6
#
#       Width  Tendency  NSP
# 1115   39.0       0.0  1.0
# 1458   35.0       0.0  1.0

# %%
data1=data.drop_duplicates()#remove duplicated rows and save in new var. data1

# %%
data1
# Out:
#               LB        AC        FM        UC        DL   DS   DP  ASTV  \
# 0     120.000000  0.000000  0.000000  0.000000  0.000000  0.0  0.0  73.0
# 1     132.000000  0.006380  0.000000  0.006380  0.003190  0.0  0.0  17.0
# 2     133.000000  0.003322  0.000000  0.008306  0.003322  0.0  0.0  16.0
# 3     134.000000  0.002561  0.000000  0.007742  0.002561  0.0  0.0  16.0
# 4     131.948232  0.006515  0.000000  0.008143  0.000000  0.0  0.0  16.0
# ...          ...       ...       ...       ...       ...  ...  ...   ...
# 2121  140.000000  0.000000  0.961268  0.007426  0.000000  0.0  0.0  79.0
# 2122  140.000000  0.000775  0.000000  0.006979  0.000000  0.0  0.0  78.0
# 2123  140.000000  0.000980  0.000000  0.006863  0.000000  0.0  0.0  79.0
# 2124  140.000000  0.000679  0.000000  0.006110  0.000000  0.0  0.0  78.0
# 2125  142.000000  0.001616 -0.000188  0.008078  0.000000  0.0  0.0  74.0
#
#       MSTV       ALTV  MLTV  Width  Tendency       NSP
# ...

# %%
data1[data1.duplicated()] #print duplicated rows
# Out:
# Empty DataFrame
# Columns: [LB, AC, FM, UC, DL, DS, DP, ASTV, MSTV, ALTV, MLTV, Width, Tendency, NSP]
# Index: []

# %% [markdown]
# Handle missing values appropriately (e.g., imputation, deletion).
#
# After removing duplicated rows from the dataset, now we can treat null values using Imputation technique. Imputation technique is used for replacing the missing data with some substitute values to retain most of the data/information of the dataset. These substitute values can be either mean, median or mode. Let's treat null values of some columns using mean, some columns using median and some columns using mode.

# %% [markdown]
# we can treat null values of columns:LB,AC,DS,DP using mean

# %%
mean=data['LB'].mean()
mean
# Out:
# 133.34359835512115

# %%
data1['LB'].fillna(mean,inplace=True)
# Out:
# C:\Users\LAPTOPCOM\AppData\Local\Temp\ipykernel_1040\755209439.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data1['LB'].fillna(mean,inplace=True)
# C:\Users\LAPTOPCOM\AppData\Local\Temp\ipykernel_1040\755209439.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['LB'].fillna(mean,inplace=True)

# %%
data1.isnull().sum()
# Out:
# LB           0
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
mean1=data1['AC'].mean()
mean1
# Out:
# 0.0032197961539923953

# %%
data1['AC'].fillna(mean1,inplace=True)
# Out:
# C:\Users\LAPTOPCOM\AppData\Local\Temp\ipykernel_1040\3689557361.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data1['AC'].fillna(mean1,inplace=True)
# C:\Users\LAPTOPCOM\AppData\Local\Temp\ipykernel_1040\3689557361.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['AC'].fillna(mean1,inplace=True)

# %%
data1.isnull().sum()
# Out:
# LB           0
# AC           0
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
mean2=data1['DS'].mean()
mean2
# Out:
# 2.5113755582501185e-06

# %%
data1['DS'].fillna(mean2,inplace=True)
# Out:
# C:\Users\LAPTOPCOM\AppData\Local\Temp\ipykernel_1040\1543244708.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data1['DS'].fillna(mean2,inplace=True)
# C:\Users\LAPTOPCOM\AppData\Local\Temp\ipykernel_1040\1543244708.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['DS'].fillna(mean2,inplace=True)

# %%
data1.isnull().sum()
# Out:
# LB           0
# AC           0
# FM           0
# UC           0
# DL           0
# DS           0
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
mean3=data1['DP'].mean()

# %%
mean3
# Out:
# 0.0001753177950546838

# %%
data1['DP'].fillna(mean3,inplace=True)
# Out:
# C:\Users\LAPTOPCOM\AppData\Local\Temp\ipykernel_1040\771551423.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data1['DP'].fillna(mean3,inplace=True)
# C:\Users\LAPTOPCOM\AppData\Local\Temp\ipykernel_1040\771551423.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['DP'].fillna(mean3,inplace=True)

# %%
data1.isnull().sum()
# Out:
# LB           0
# AC           0
# FM           0
# UC           0
# DL           0
# DS           0
# DP           0
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %% [markdown]
# Null values of Columns: MLTV, Width can be treated using median

# %%
median=data1['MLTV'].median() #calculate median of col. MLTV

# %%
median
# Out:
# 7.4

# %%
data1['MLTV'].fillna(median,inplace=True)
# Out:
# C:\Users\LAPTOPCOM\AppData\Local\Temp\ipykernel_1040\3824535194.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data1['MLTV'].fillna(median,inplace=True)
# C:\Users\LAPTOPCOM\AppData\Local\Temp\ipykernel_1040\3824535194.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['MLTV'].fillna(median,inplace=True)

# %%
data1.isnull().sum()
# Out:
# LB           0
# AC           0
# FM           0
# UC           0
# DL           0
# DS           0
# DP           0
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV         0
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %%
median1=data1['Width'].median()
median1
# Out:
# 67.4864681

# %%
data1['Width'].fillna(median1,inplace=True)
# Out:
# C:\Users\LAPTOPCOM\AppData\Local\Temp\ipykernel_1040\1742906627.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data1['Width'].fillna(median1,inplace=True)
# C:\Users\LAPTOPCOM\AppData\Local\Temp\ipykernel_1040\1742906627.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['Width'].fillna(median1,inplace=True)

# %%
data1.isnull().sum()
# Out:
# LB           0
# AC           0
# FM           0
# UC           0
# DL           0
# DS           0
# DP           0
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV         0
# Width        0
# Tendency    21
# NSP         21
# dtype: int64

# %% [markdown]
# Null values of columns: Tendency,NSP can be treated using mode. Use mode specifying it's index position

# %%
mode=data1['Tendency'].mode()

# %%
mode
# Out:
# 0    0.0
# Name: Tendency, dtype: float64

# %%
data1['Tendency'].fillna(mode[0],inplace=True)
# Out:
# C:\Users\LAPTOPCOM\AppData\Local\Temp\ipykernel_1040\2528939885.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data1['Tendency'].fillna(mode[0],inplace=True)
# C:\Users\LAPTOPCOM\AppData\Local\Temp\ipykernel_1040\2528939885.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['Tendency'].fillna(mode[0],inplace=True)

# %%
data1.isnull().sum()
# Out:
# LB           0
# AC           0
# FM           0
# UC           0
# DL           0
# DS           0
# DP           0
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV         0
# Width        0
# Tendency     0
# NSP         21
# dtype: int64

# %%
mode1=data1['NSP'].mode()
mode1
# Out:
# 0    1.0
# Name: NSP, dtype: float64

# %%
data1['NSP'].fillna(mode1[0],inplace=True)
# Out:
# C:\Users\LAPTOPCOM\AppData\Local\Temp\ipykernel_1040\3995200089.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data1['NSP'].fillna(mode1[0],inplace=True)
# C:\Users\LAPTOPCOM\AppData\Local\Temp\ipykernel_1040\3995200089.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1['NSP'].fillna(mode1[0],inplace=True)

# %%
data.isnull().sum()
# Out:
# LB          21
# AC          20
# FM           0
# UC           0
# DL           0
# DS          21
# DP          21
# ASTV         0
# MSTV         0
# ALTV         0
# MLTV        21
# Width       21
# Tendency    21
# NSP         21
# dtype: int64

# %% [markdown]
# Identify and correct any inconsistencies in data types (e.g., numerical values stored as strings).

# %%
data1.dtypes
# Out:
# LB          float64
# AC          float64
# FM          float64
# UC          float64
# DL          float64
# DS          float64
# DP          float64
# ASTV        float64
# MSTV        float64
# ALTV        float64
# MLTV        float64
# Width       float64
# Tendency    float64
# NSP         float64
# dtype: object

# %% [markdown]
# as we can see, data type of each and every column is float64 because each column has numerical values. So, there is no inconsistency in data types.

# %% [markdown]
# Detect and treat outliers if necessary
#
# It will also cover data visulaization (Create histograms or boxplots to visualize the distributions of various numerical variables)

# %%
data1['LB'].hist()
# Out:
# <Axes: >

# %% [markdown]
# Range of LB: 0-220. Here, data has both left and right skewness. Data is left skewed and we can see the outliers within the range (55-65). Data is right skewed and we can see outliers within the range (198-218)

# %%
import matplotlib.pyplot as plt #boxplot function available in this lib

# %%
plt.boxplot(data1['LB'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1cb8f929f10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1cb8f92a4b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1cb8f929c70>],
#  'medians': [<matplotlib.lines.Line2D at 0x1cb8f92a960>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1cb8f92ac00>],
#  'means': []}

# %% [markdown]
# Range of LB: 0-220. Data is both left and right skewed. IQR(Inter Quartile Range)= 140-125 = 15 (approx.). Range from 0-60: 1 outlier which must be removed from the dataset. Range from 200-220: 1 outlier which must be removed from the dataset
#
# we can also code (as shown below) for plotting the boxplot

# %%
data1.boxplot(column='LB')
plt.show()

# %% [markdown]
# let's treat outliers using drop function from pandas library => pass parameters axis=0 and inplace = True inside drop function. Axis =0 for rows since we are removing outliers from the rows with respect to a column. Bidefault, inplace = False, so, to reflect change in the dataset, we have to pass inplace = True.

# %% [markdown]
# Treat outlier in col LB: only one point above 200 and one point below 60 but majority of the data points of col. LB lies from 110 to 160 => so remove these 2 outliers from the dataset

# %%
data1.drop(data1[data1['LB'] > 200].index,axis=0,inplace=True) # remove one outlier above 200 
data1.drop(data1[data1['LB'] < 60].index,axis=0,inplace=True)   #remove one outlier below 60
# Out:
# C:\Users\LAPTOPCOM\AppData\Local\Temp\ipykernel_1040\2288313929.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1.drop(data1[data1['LB'] > 200].index,axis=0,inplace=True) # remove one outlier above 200
# C:\Users\LAPTOPCOM\AppData\Local\Temp\ipykernel_1040\2288313929.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1.drop(data1[data1['LB'] < 60].index,axis=0,inplace=True)   #remove one outlier below 60

# %%
plt.boxplot(data1['LB']) #outliers above  200 and below 60 has been removed
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1cb8f7e75c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1cb8f7e7b60>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1cb8f7e72f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1cb8f804080>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1cb8f804320>],
#  'means': []}

# %%
#Column AC

data1['AC'].hist()
# Out:
# <Axes: >

# %% [markdown]
# Range of AC: -0.02 to 0.04. Here, data has both left and right skewness. Data is left skewed and we can see the outliers within the range (-0.02 to -0.01). Data is right skewed and we can see outliers within the range (0.015 to 0.022)

# %%
plt.boxplot(data1['AC'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1cb8b9cb4d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1cb8bb19190>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1cb8cd77620>],
#  'medians': [<matplotlib.lines.Line2D at 0x1cb8d03fec0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1cb8cbeef30>],
#  'means': []}

# %% [markdown]
# Range of AC: -0.02 to 0.04. Data is both left and right skewed. IQR(Inter Quartile Range)= 0.005-0.00=0.005 (approx.). Range from -0.02 to -0.01: 1 outlier which must be removed from the dataset.Range from 0.01 to 0.02 is very dense, so, we should not consider them as outliers else we may lose some valuable information from the dataset. Range from 0.03 to 0.04: 1 outlier which must be removed from the dataset

# %% [markdown]
# Treat outlier in col AC: only one point above 0.03 and one point below -0.01 but majority of the data points of col. AC lies from 0.00 to 0.02 => so remove these 2 outliers from the dataset

# %%
data1.drop(data1[data1['AC']>0.03].index,axis=0,inplace=True)# remove one outlier above 0.03
data1.drop(data1[data1['AC'] < -0.01].index,axis=0,inplace=True)   #remove one outlier below -0.0
# Out:
# C:\Users\LAPTOPCOM\AppData\Local\Temp\ipykernel_1040\2613896751.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1.drop(data1[data1['AC']>0.03].index,axis=0,inplace=True)# remove one outlier above 0.03
# C:\Users\LAPTOPCOM\AppData\Local\Temp\ipykernel_1040\2613896751.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1.drop(data1[data1['AC'] < -0.01].index,axis=0,inplace=True)   #remove one outlier below -0.0

# %%
plt.boxplot(data1['AC'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1cb8f986540>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1cb8cfd45f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1cb8f9c7500>],
#  'medians': [<matplotlib.lines.Line2D at 0x1cb88affda0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1cb8e174aa0>],
#  'means': []}

# %%
#Column: FM

data1['FM'].hist()
# Out:
# <Axes: >

# %% [markdown]
# Range of FM: -0.6 to 1.0 . Here, data has both left and right skewness. Data is left skewed and we can see the outliers within the range (-0.5 to -0.3). Data is right skewed and we can see outliers within the range (0.1 to 0.5)

# %%
plt.boxplot(data1['FM'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1cb8fbea5d0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1cb8fbeab40>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1cb8f9c5df0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1cb8fbeaff0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1cb8fbeb2c0>],
#  'means': []}

# %% [markdown]
# Range of FM: -0.6 to 1.0 . Data is both left and right skewed. IQR(Inter Quartile Range)= 0.0 (approx.). Range from -0.6 to -0.4: 1 outlier which must be removed from the dataset.Range from 0.0 to 0.6 is very dense, so, we should not consider them as outliers else we may lose some valuable information from the dataset. Range from 0.8 to 1.0: 1 outlier which must be removed from the dataset

# %% [markdown]
# Treat outlier in col FM: only one point above 0.8 and one point below -0.4 but majority of the data points of col. FM lies from 0.0 to 0.6 => so remove these 2 outliers from the dataset

# %%
data1.drop(data1[data1['FM']>0.8].index,axis=0,inplace=True) # remove one outlier above 0.8
data1.drop(data1[data1['FM'] < -0.4].index,axis=0,inplace=True)   #remove one
# Out:
# C:\Users\LAPTOPCOM\AppData\Local\Temp\ipykernel_1040\1756679210.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1.drop(data1[data1['FM']>0.8].index,axis=0,inplace=True) # remove one outlier above 0.8
# C:\Users\LAPTOPCOM\AppData\Local\Temp\ipykernel_1040\1756679210.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1.drop(data1[data1['FM'] < -0.4].index,axis=0,inplace=True)   #remove one

# %%
plt.boxplot(data1['FM']) # outliers above 0.8 and below -0.4 have been removed
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1cb90c51370>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1cb90c51970>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1cb90c510a0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1cb8fbd94c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1cb90c51eb0>],
#  'means': []}

# %% [markdown]
# column : UC

# %%
data1['UC'].hist()
# Out:
# <Axes: >

# %% [markdown]
# Range of UC: -0.005 to 0.03 . Here, data has both left and right skewness. Data is left skewed and we can see the outliers within the range (-0.005 to -0.01). Data is right skewed and we can see outliers within the range (0.012 to 0.017, 0.025 to 0.03)

# %%
plt.boxplot(data1['UC'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1cb90d06e40>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1cb90d073b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1cb90d06c90>],
#  'medians': [<matplotlib.lines.Line2D at 0x1cb90d07800>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1cb90d07a40>],
#  'means': []}

# %% [markdown]
# Range of UC: -0.005 to 0.03 . Data is both left and right skewed. IQR(Inter Quartile Range)= 0.01 (approx.). Range from -0.005 to -0.01: 1 outlier which must be removed from the dataset.Range from 0.01 to 0.02 is very dense, so, we should not consider them as outliers else we may lose some valuable information from the dataset. Range from 0.02 to 0.03: 1 outlier which must be removed from the dataset

# %% [markdown]
# Treat outlier in col UC: only one point above 0.02 and one point below -0.01 but majority of the data points of col. UC lies from 0.00 to 0.02 => so remove these 2 outliers from the dataset

# %%
data1.drop(data1[data1['UC'] > 0.02].index,axis=0,inplace=True) # remove one outlier above 0.02
data1.drop(data1[data1['UC'] < -0.01].index,axis=0,inplace=True)   #remove one
# Out:
# C:\Users\LAPTOPCOM\AppData\Local\Temp\ipykernel_1040\2921074817.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1.drop(data1[data1['UC'] > 0.02].index,axis=0,inplace=True) # remove one outlier above 0.02
# C:\Users\LAPTOPCOM\AppData\Local\Temp\ipykernel_1040\2921074817.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1.drop(data1[data1['UC'] < -0.01].index,axis=0,inplace=True)   #remove one

# %%
plt.boxplot(data1['UC'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1cb8fa80500>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1cb8fa80b30>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1cb8fa801d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1cb8fa80fb0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1cb8fa812b0>],
#  'means': []}

# %%
data1['DL'].hist()
# Out:
# <Axes: >

# %% [markdown]
# Range of DL: -0.005 to 0.03 . Here, data has both left and right skewness. Data is left skewed and we can see the outliers within the range (-0.005 to -0.01). Data is right skewed and we can see outliers within the range (0.012 to 0.017, 0.025 to 0.03)

# %%
plt.boxplot(data1['DL'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1cb90ea1880>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1cb90ea1d60>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1cb90ea1580>],
#  'medians': [<matplotlib.lines.Line2D at 0x1cb90ea21b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1cb90ea2450>],
#  'means': []}

# %% [markdown]
# Treat outlier in col DL: only one point above 0.02 and one point below -0.01 but majority of the data points of col. DL lies from 0.00 to 0.02 => so remove these 2 outliers from the dataset

# %%
data1.drop(data1[data1['DL'] > 0.02].index,axis=0,inplace=True) # remove one outlier above 0.02
data1.drop(data1[data1['DL'] < -0.01].index,axis=0,inplace=True)   #remove one outlier below -0.01
# Out:
# C:\Users\LAPTOPCOM\AppData\Local\Temp\ipykernel_1040\294824946.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1.drop(data1[data1['DL'] > 0.02].index,axis=0,inplace=True) # remove one outlier above 0.02
# C:\Users\LAPTOPCOM\AppData\Local\Temp\ipykernel_1040\294824946.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1.drop(data1[data1['DL'] < -0.01].index,axis=0,inplace=True)   #remove one outlier below -0.01

# %%
plt.boxplot(data['DL'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1cb90eea660>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1cb90eeac90>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1cb90eea450>],
#  'medians': [<matplotlib.lines.Line2D at 0x1cb90eeb0e0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1cb90eeb320>],
#  'means': []}

# %% [markdown]
# Column :DS

# %%
data1['DS'].hist()
# Out:
# <Axes: >

# %% [markdown]
# Range of DS: -0.0015 to 0.0025. Here, data has both left and right skewness. Data is left skewed and we can see the outliers within the range (-0.0015 to -0.0010). Data is right skewed and we can see outliers within the range (0.0025 to 0.0030)

# %%
plt.boxplot(data1['DS'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1cb90dcc3b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1cb90dcc980>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1cb90dcc110>],
#  'medians': [<matplotlib.lines.Line2D at 0x1cb90dcce60>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1cb90dcd0a0>],
#  'means': []}

# %% [markdown]
# Range of DS: -0.0015 to 0.0025 . Data is both left and right skewed. IQR(Inter Quartile Range)= 0.0000 (approx.). Range from -0.0015 to -0.0010: 1 outlier which must be removed from the dataset.Range from 0.0005 to 0.0015 is very dense, so, we should not consider them as outliers else we may lose some valuable information from the dataset. Range from 0.0025 to 0.0030: 1 outlier which must be removed from the dataset

# %% [markdown]
# Treat outlier in col DS: only one point above 0.0025 and one point below -0.0010 but majority of the data points of col. DS lies from 0.0000 to 0.0015 => so remove these 2 outliers from the dataset

# %%
data1.drop(data1[data1['DS'] > 0.0025].index,axis=0,inplace=True) # remove one outlier above 0.0025
data1.drop(data1[data1['DS'] < -0.0010].index,axis=0,inplace=True)   #remove one outlier below -0.0010
# Out:
# C:\Users\LAPTOPCOM\AppData\Local\Temp\ipykernel_1040\3208756132.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1.drop(data1[data1['DS'] > 0.0025].index,axis=0,inplace=True) # remove one outlier above 0.0025
# C:\Users\LAPTOPCOM\AppData\Local\Temp\ipykernel_1040\3208756132.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1.drop(data1[data1['DS'] < -0.0010].index,axis=0,inplace=True)   #remove one outlier below -0.0010

# %%
plt.boxplot(data1['DS'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1cb8a10d1c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1cb8a10d760>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1cb8a10cf50>],
#  'medians': [<matplotlib.lines.Line2D at 0x1cb8a066bd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1cb8a10dbb0>],
#  'means': []}

# %% [markdown]
# #

# %% [markdown]
# Column: DP

# %%
data1['DP'].hist()
# Out:
# <Axes: >

# %% [markdown]
# Range of DP: -0.006 to 0.010. Here, data has both left and right skewness. Data is left skewed and we can see the outliers within the range (-0.006 to -0.004). Data is right skewed and we can see outliers within the range (0.009 to 0.012)

# %%
plt.boxplot(data1['DP'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1cb8a423fe0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1cb8a228560>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1cb8a423da0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1cb8a2289b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1cb8a228c80>],
#  'means': []}

# %% [markdown]
# Range of DP: -0.006 to 0.010 . Data is both left and right skewed. IQR(Inter Quartile Range)= 0.000 (approx.). Range from -0.006 to -0.004: 1 outlier which must be removed from the dataset.Range from 0.000 to 0.006 is very dense, so, we should not consider them as outliers else we may lose some valuable information from the dataset. Range from 0.010 to 0.012: 1 outlier which must be removed from the dataset

# %% [markdown]
# Treat outlier in col DP: only one point above 0.010 and one point below -0.004 but majority of the data points of col. DP lies from 0.000 to 0.006 => so remove these 2 outliers from the dataset

# %%
data1.drop(data1[data1['DP'] > 0.010].index,axis=0,inplace=True) # remove one outlier above 0.010
data1.drop(data1[data1['DP'] < -0.004].index,axis=0,inplace=True)   #remove one outlier below -0.004

# %%
plt.boxplot(data1['DP']) # outliers above 0.010 and below -0.004 have been rem
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1cb8a467320>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1cb8a467920>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1cb8a467050>],
#  'medians': [<matplotlib.lines.Line2D at 0x1cb8a467e30>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1cb8a4a00e0>],
#  'means': []}

# %% [markdown]
# we can see one more outlier above 0.005=> so remove it

# %%
data1.drop(data1[data1['DP']>0.005].index,axis=0,inplace=True)

# %%
plt.boxplot(data1['DP'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1cb8a6066c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1cb8a606c30>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1cb8a606450>],
#  'medians': [<matplotlib.lines.Line2D at 0x1cb8a607050>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1cb8a6072f0>],
#  'means': []}

# %% [markdown]
# column:ASTV

# %%
data1['ASTV'].hist()
# Out:
# <Axes: >

# %% [markdown]
# Range of ASTV: -60 to 150. Here, data has both left and right skewness. Data is left skewed and we can see the outliers within the range (-60 to -40). Data is right skewed and we can see outliers within the range (140 to 160)

# %%
plt.boxplot(data1['ASTV']) #boxplot for col. ASTV
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1cb8a39cd10>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1cb8a39cfb0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1cb8a1d6780>],
#  'medians': [<matplotlib.lines.Line2D at 0x1cb8a064230>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1cb88be1c10>],
#  'means': []}

# %% [markdown]
# Range of ASTV: -60 to 150 . Data is both left and right skewed. IQR(Inter Quartile Range)= 55-45=10 (approx.). Range from -60 to -50: 1 outlier which must be removed from the dataset. Range from 150 to 155: 1 outlier which must be removed from the dataset

# %% [markdown]
# Treat outlier in col ASTV: only one point above 150 and one point below -50 but majority of the data points of col. ASTV lies from 0 to 100 => so remove these 2 outliers from the dataset

# %%
data1.drop(data1[data1['ASTV'] > 150].index,axis=0,inplace=True) # remove one outlier above 150
data1.drop(data1[data1['ASTV'] < -50].index,axis=0,inplace=True)   #remove one outlier below -50
# Out:
# C:\Users\LAPTOPCOM\AppData\Local\Temp\ipykernel_1040\1169291311.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1.drop(data1[data1['ASTV'] > 150].index,axis=0,inplace=True) # remove one outlier above 150
# C:\Users\LAPTOPCOM\AppData\Local\Temp\ipykernel_1040\1169291311.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1.drop(data1[data1['ASTV'] < -50].index,axis=0,inplace=True)   #remove one outlier below -50

# %%
plt.boxplot(data1['ASTV'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1cb90dfef30>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1cb90dff530>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1cb90dcf9e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1cb90dff980>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1cb90dffbf0>],
#  'means': []}

# %%
data1['MSTV'].hist()
# Out:
# <Axes: >

# %% [markdown]
# Range of MSTV: -7.5 to 12.5 . Data is both left and right skewed. Data is left skewed and we can see the outliers within the range (-7.5 to -5.0). Data is right skewed and we can see outliers within the range (5.2 to 7.5, 11 to 12.55)

# %%
plt.boxplot(data1['MSTV'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1cb8b9b4320>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1cb8b9b4890>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1cb89fa0c50>],
#  'medians': [<matplotlib.lines.Line2D at 0x1cb8b9b4d10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1cb8b9b5010>],
#  'means': []}

# %% [markdown]
# Range of MSTV: -7.5 to 12.5 . Data is both left and right skewed. IQR(Inter Quartile Range)=2.3 (approx.). Range from -7.5 to -5.0: 1 outlier which must be removed from the dataset.Range from 2.5 to 7.5 is very dense, so, we should not consider them as outliers else we may lose some valuable information from the dataset. Range from 12.5 to 13.0: 1 outlier which must be removed from the dataset

# %% [markdown]
# Treat outlier in col MSTV: only one point above 12.5 and one point below -5.0 but majority of the data points of col. MSTV lies from 0.0 to 7.5 => so remove these 2 outliers from the dataset

# %%
data1.drop(data1[data1['MSTV'] > 12.5].index,axis=0,inplace=True) # remove one outlier above 12.5
data1.drop(data1[data1['MSTV'] < -5.0].index,axis=0,inplace=True)   #remove one outlier below -5.0

# %%
plt.boxplot(data1['MSTV']) # outliers above 12.5 and below -5.0 have been removed
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1cb8ba660c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1cb8ba66660>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1cb8ba65e80>],
#  'medians': [<matplotlib.lines.Line2D at 0x1cb8ba66ae0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1cb8ba66e10>],
#  'means': []}

# %% [markdown]
# Column: ALTV

# %%
data1['ALTV'].hist()
# Out:
# <Axes: >

# %% [markdown]
# Range of ALTV: -100 to 150. Data is both left and right skewed. Data is left skewed and we can see the outliers within the range (-100 to -50). Data is right skewed and we can see outliers within the range (150 to 155)

# %%
plt.boxplot(data1['ALTV']) #boxplot for col. ALTV
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1cb8ce29760>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1cb8ce29d30>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1cb8ce29520>],
#  'medians': [<matplotlib.lines.Line2D at 0x1cb8ce2a1b0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1cb8ce2a420>],
#  'means': []}

# %% [markdown]
# Range of ALTV: -100 to 150 . Data is both left and right skewed. IQR(Inter Quartile Range)=10 (approx.). Range from -100 to-50: 1 outlier which must be removed from the dataset.Range from 20 to 100 is very dense, so, we should not consider them as outliers else we may lose some valuable information from the dataset. Range from 150 to 160: 1 outlier which must be removed from the dataset

# %% [markdown]
# Treat outlier in col ALTV: only one point above 150 and one point below -50 but majority of the data points of col. ALTV lies from 0 to 100 => so remove these 2 outliers from the dataset

# %%
data1.drop(data1[data1['ALTV'] > 150].index,axis=0,inplace=True) # remove one outlier above 150
data1.drop(data1[data1['ALTV'] < -50].index,axis=0,inplace=True)   #remove one outlier below -50

# %%
plt.boxplot(data1['ALTV'])# outliers above 150 and below -50 have been removed
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1cb8cbb0920>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1cb8cbb0f20>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1cb8cbb06e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1cb8cbb13d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1cb8cbb1700>],
#  'means': []}

# %% [markdown]
# column:MLTV

# %%
data1['MLTV'].hist()
# Out:
# <Axes: >

# %% [markdown]
# Range of MLTV: -50 to 100. Data is both left and right skewed. Data is left skewed and we can see the outliers within the range (-50 to -38). Data is right skewed and we can see outliers within the range (22-40, 82-100)

# %%
plt.boxplot(data1['MLTV']) #boxplot for col MLTV
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1cb8e13d760>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1cb8e13dc70>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1cb8e13d460>],
#  'medians': [<matplotlib.lines.Line2D at 0x1cb8e13e0f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1cb8e13e3f0>],
#  'means': []}

# %% [markdown]
# Range of MLTV: -50 to 100 . Data is both left and right skewed. IQR(Inter Quartile Range)=5 (approx.). Range from -50 to-40: 1 outlier which must be removed from the dataset.Range from 20 to 60 is very dense, so, we should not consider them as outliers else we may lose some valuable information from the dataset. Range from 100 to 110: 1 outlier which must be removed from the dataset

# %% [markdown]
# Treat outlier in col MLTV: only one point above 80 and one point below -40 but majority of the data points of col. MLTV lies from 0 to 60 => so remove these 2 outliers from the datase

# %%
data1.drop(data1[data1['MLTV'] > 80].index,axis=0,inplace=True) # remove one outlier above 80
data1.drop(data1[data1['MLTV'] < -40].index,axis=0,inplace=True)   #remove one outlier below -40

# %%
plt.boxplot(data1['MLTV'])# ouliers above 80 and below -40 has been removed
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1cb8cee9ca0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1cb8ceea2a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1cb8cee9a00>],
#  'medians': [<matplotlib.lines.Line2D at 0x1cb8ceea6c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1cb8ceea990>],
#  'means': []}

# %% [markdown]
# now two more outliers are above 50 so we have to remove it

# %%
data1.drop(data1[data1['MLTV']>40].index,axis=0,inplace=True)

# %%
plt.boxplot(data1['MLTV'] )
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1cb8e2fd7c0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1cb8e2fddc0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1cb8e2fd4f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1cb8e2fe210>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1cb8e2fe4e0>],
#  'means': []}

# %% [markdown]
# Column:Width

# %%
data1['Width'].hist()
# Out:
# <Axes: >

# %% [markdown]
# Range of Width: -200 to 300. Data is both left and right skewed. Data is left skewed and we can see the outliers within the range (-200 to -100). Data is right skewed and we can see outliers within the range (300-350)

# %%
plt.boxplot(data1['Width'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1cb91051310>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1cb910518b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1cb90ff7cb0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1cb91051d30>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1cb91051fa0>],
#  'means': []}

# %% [markdown]
# Range of Width: -200 to 300 . Data is both left and right skewed. IQR(Inter Quartile Range)=100-10=90 (approx.). Range from -200 to-100: 1 outlier which must be removed from the dataset. Range from 300 to 350: 1 outlier which must be removed from the dataset

# %%
data1.drop(data1[data1['Width'] > 300].index,axis=0,inplace=True) # remove one outlier above 300
data1.drop(data1[data1['Width'] < -100].index,axis=0,inplace=True)   #remove one outlier below -100
# Out:
# C:\Users\LAPTOPCOM\AppData\Local\Temp\ipykernel_1040\1076678304.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1.drop(data1[data1['Width'] > 300].index,axis=0,inplace=True) # remove one outlier above 300
# C:\Users\LAPTOPCOM\AppData\Local\Temp\ipykernel_1040\1076678304.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1.drop(data1[data1['Width'] < -100].index,axis=0,inplace=True)   #remove one outlier below -100

# %%
plt.boxplot(data1['Width']) # outliers above 300 and below -100 have been removed
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1cb910b2630>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1cb910b2bd0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1cb910521b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1cb910b3080>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1cb910b3380>],
#  'means': []}

# %% [markdown]
# Column:Tendency

# %%
data1['Tendency'].hist()
# Out:
# <Axes: >

# %% [markdown]
# Range of Tendency: -3 to 3. Data is both left and right skewed. Data is left skewed and we can see the outliers within the range (-3 to -2.5). Data is right skewed and we can see outliers within the range (2.5 to 3)

# %%
plt.boxplot(data1['Tendency'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1cb9217e120>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1cb9217e660>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1cb9217de80>],
#  'medians': [<matplotlib.lines.Line2D at 0x1cb9217eae0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1cb9217ede0>],
#  'means': []}

# %% [markdown]
# Range of Tendency: -3 to 3 . Data is both left and right skewed. IQR(Inter Quartile Range)=1 (approx.). Range from -3 to-2: 1 outlier which must be removed from the dataset. Range from 2 to 3: 1 outlier which must be removed from the dataset

# %% [markdown]
# data1.drop(data1[data1['Tendency'] > 2].index,axis=0,inplace=True) # remove one outlier above 2
# data1.drop(data1[data1['Tendency'] < -2].index,axis=0,inplace=True)   #remove one outlier below -2

# %%
data1.drop(data1[data1['Tendency'] > 2].index,axis=0,inplace=True) # remove one outlier above 2
data1.drop(data1[data1['Tendency'] < -2].index,axis=0,inplace=True)   #remove one outlier below -2
plt.boxplot(data1['Tendency']) # outliers above 2 and below -2 have been removed
# Out:
# C:\Users\LAPTOPCOM\AppData\Local\Temp\ipykernel_1040\1682856716.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1.drop(data1[data1['Tendency'] > 2].index,axis=0,inplace=True) # remove one outlier above 2
# C:\Users\LAPTOPCOM\AppData\Local\Temp\ipykernel_1040\1682856716.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1.drop(data1[data1['Tendency'] < -2].index,axis=0,inplace=True)   #remove one outlier below -2
# {'whiskers': [<matplotlib.lines.Line2D at 0x1cb92488fb0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1cb92489580>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1cb92488d10>],
# ...

# %% [markdown]
# Column:NSP

# %%
data1['NSP'].hist()
# Out:
# <Axes: >

# %% [markdown]
# Range of NSP: -1 to 5. Data is both left and right skewed. Data is left skewed and we can see the outliers within the range (-1 to -0.5 . Data is right skewed and we can see outliers within the range (4.5 to 5)

# %%
plt.boxplot(data['NSP'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1cb9256bfb0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1cb925a85f0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1cb9256bd40>],
#  'medians': [<matplotlib.lines.Line2D at 0x1cb925a8ad0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1cb925a8da0>],
#  'means': []}

# %% [markdown]
# Range of NSP: -1 to 5 . Data is both left and right skewed. IQR(Inter Quartile Range)=1 (approx.). Range from -1 to 0: 1 outlier which must be removed from the dataset.Range from 1 to 3 is dense, so, we should not consider them as outliers else we may lose some valuable information from the dataset. Range from 4 to 5: 1 outlier which must be removed from the dataset

# %%
data1.drop(data1[data1['NSP'] > 4].index,axis=0,inplace=True) # remove one outlier above 4
data1.drop(data1[data1['NSP'] < 0].index,axis=0,inplace=True)   #remove one outlier below 0
# Out:
# C:\Users\LAPTOPCOM\AppData\Local\Temp\ipykernel_1040\578801962.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1.drop(data1[data1['NSP'] > 4].index,axis=0,inplace=True) # remove one outlier above 4
# C:\Users\LAPTOPCOM\AppData\Local\Temp\ipykernel_1040\578801962.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data1.drop(data1[data1['NSP'] < 0].index,axis=0,inplace=True)   #remove one outlier below 0

# %%
plt.boxplot(data1['NSP']) # outliers above 4 and below 0 have been removed
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1cb927796a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1cb92779c10>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1cb92737500>],
#  'medians': [<matplotlib.lines.Line2D at 0x1cb9277a150>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1cb9277a480>],
#  'means': []}

# %% [markdown]
# #2. Statical Summary
#
# Provide a statistical summary for each variable in the dataset, including measures of central tendency (mean, median) and dispersion (standard deviation, interquartile range).

# %%
data1.describe()
# Out:
#                 LB           AC           FM           UC           DL  \
# count  2028.000000  2028.000000  2028.000000  2028.000000  2028.000000
# mean    133.258014     0.003159     0.009369     0.004377     0.001900
# std       9.790116     0.003831     0.046124     0.002945     0.002976
# min     106.000000    -0.000185    -0.005106    -0.000132    -0.000124
# 25%     126.000000     0.000000     0.000000     0.001880     0.000000
# 50%     133.000000     0.001681     0.000000     0.004505     0.000000
# 75%     140.000000     0.005480     0.002582     0.006570     0.003304
# max     160.000000     0.019284     0.480634     0.014925     0.015385
#
#                 DS           DP         ASTV         MSTV         ALTV  \
# count  2028.000000  2028.000000  2028.000000  2028.000000  2028.000000
# mean      0.000003     0.000175    46.993158     1.368676    10.262678
# std       0.000060     0.000840    17.183076     1.139916    21.328516
# ...

# %%
mean=data1.mean()

# %%
mean
# Out:
# LB          133.258014
# AC            0.003159
# FM            0.009369
# UC            0.004377
# DL            0.001900
# DS            0.000003
# DP            0.000175
# ASTV         46.993158
# MSTV          1.368676
# ALTV         10.262678
# MLTV          8.282969
# Width        70.336846
# Tendency      0.316563
# NSP           1.301297
# dtype: float64

# %%
median=data1.median()
median
# Out:
# LB          133.000000
# AC            0.001681
# FM            0.000000
# UC            0.004505
# DL            0.000000
# DS            0.000000
# DP            0.000000
# ASTV         49.000000
# MSTV          1.200000
# ALTV          0.000000
# MLTV          7.400000
# Width        67.486468
# Tendency      0.000000
# NSP           1.000000
# dtype: float64

# %%
from scipy import stats

# %%
stats.mode(data1) #calculate mode of all columns
# Out:
# ModeResult(mode=array([133. ,   0. ,   0. ,   0. ,   0. ,   0. ,   0. ,  65. ,   0.4,
#          0. ,   0. ,  39. ,   0. ,   1. ]), count=array([ 124.,  800., 1181.,  299., 1114., 1901., 1732.,   58.,  112.,
#        1112.,  120.,   41., 1013., 1503.]))

# %%
std=data1.std() #std of all columns
std
# Out:
# LB           9.790116
# AC           0.003831
# FM           0.046124
# UC           0.002945
# DL           0.002976
# DS           0.000060
# DP           0.000840
# ASTV        17.183076
# MSTV         1.139916
# ALTV        21.328516
# MLTV         7.706781
# Width       38.763945
# Tendency     0.609314
# NSP          0.610403
# dtype: float64

# %% [markdown]
# Inter QUartile Range
#
# IQR=Q3-Q1

# %%
Q1=data1.quantile(0.25)
Q1
# Out:
# LB          126.00000
# AC            0.00000
# FM            0.00000
# UC            0.00188
# DL            0.00000
# DS            0.00000
# DP            0.00000
# ASTV         32.00000
# MSTV          0.70000
# ALTV          0.00000
# MLTV          4.60000
# Width        37.00000
# Tendency      0.00000
# NSP           1.00000
# Name: 0.25, dtype: float64

# %%
Q3=data1.quantile(0.75)
Q3
# Out:
# LB          140.000000
# AC            0.005480
# FM            0.002582
# UC            0.006570
# DL            0.003304
# DS            0.000000
# DP            0.000000
# ASTV         61.000000
# MSTV          1.700000
# ALTV         11.000000
# MLTV         10.800000
# Width       100.000000
# Tendency      1.000000
# NSP           1.000000
# Name: 0.75, dtype: float64

# %%
IQR=Q3-Q1 # IQR for each numerical column
IQR
# Out:
# LB          14.000000
# AC           0.005480
# FM           0.002582
# UC           0.004690
# DL           0.003304
# DS           0.000000
# DP           0.000000
# ASTV        29.000000
# MSTV         1.000000
# ALTV        11.000000
# MLTV         6.200000
# Width       63.000000
# Tendency     1.000000
# NSP          0.000000
# dtype: float64

# %% [markdown]
# Highlighting any interesting find from this summary
#
# Columns like LB,AC,FM,UC,DL,DS,DP,MSTV,Tendency,NSP have perfectly normal distributed data (because, mean = median = mode)
#
# Column ASTV has left skewed data i.e. majority of data lies in the right side of the mean (because, mode > median > mean)
#
# Columns like ALTV,MLTV,Width have right skewed data i.e. majority of data lies in the left side of the mean (because, mean > median > mode)
#
# If std is more => data is more spread about the mean i.e data points are more far away from the mean. Clearly, for Width,ALTV,ASTV data is relatively more spread about the mean and for DS, DP data is least spread about the mean.
#
# If IQR is more => middle 50% data is more spread and if IQR is less => middle 50% data cluster more tightly. Clearly, for Width,ASTV,LB,ALTV middle 50% data is relatively more spread and for DS, DP, NSP middle 50% data cluster more tightly

# %% [markdown]
# #3. Data Visualization
# #Create histograms or boxplots to visualize the distributions of various numerical variables
#
# :-Already completed detec and treat outliers of necessary

# %% [markdown]
# #Use bar charts or pie charts to display the frequency of categories for categorical variable
#
# :-In this dataset there is only numerical columns so there is no any categorical column

# %% [markdown]
# #Generate scatter plots or correlation heatmaps to explore relationships between pairs of variables.
#
# Scatter plots are used to visualize (without calculation) whether two variables has good correlation or not which means scatter plot just gives us assumption about the correlation between two variables whereas heatmap gives the exact value of correlation between two variables

# %%
xpoints=data1['LB']
ypoints=data1['NSP']
plt.title('scatterplot')
plt.xlabel('LB')
plt.ylabel('NSP')
plt.plot(xpoints,ypoints,'o')
plt.show()

# %%
plt.title('scatter plot')
plt.xlabel('LB')
plt.ylabel('NSP')
plt.scatter(xpoints,ypoints)
plt.show()

# %% [markdown]
# we can also draw scatter plot using scatterplot function available inside seaborn library.

# %%
import seaborn as sns

# %%
sns.scatterplot(x=data1['LB'],y=data1['NSP'])
plt.title('scatterplot')
# Out:
# Text(0.5, 1.0, 'scatterplot')

# %% [markdown]
# here, we can visualize wrt. LB, we are getting 3 constant values of NSP : 1.0, 2.0, 3.0. It's an example of no correlation as there is no proper relationship between LB and NSP

# %%
sns.scatterplot(x=data1['AC'],y=data1['NSP'])  #using scatterplot func.
plt.title('scatterplot')
# Out:
# Text(0.5, 1.0, 'scatterplot')

# %%
sns.scatterplot(x=data1['FM'],y=data1['NSP'])  #using scatterplot func.
plt.title('scatterplot')
# Out:
# Text(0.5, 1.0, 'scatterplot')

# %%
fig, ax = plt.subplots(figsize=(10, 10))  #specify size of heatmap
sns.heatmap(data1.corr(),annot=True) #create heatmap (parameter annot is used
# Out:
# <Axes: >

# %% [markdown]
# DP, ASTV are the most contributing elements which is increasing the NSP i.e. DP, ASTV are the variables which affect the NSP most because correlation value between DP and NSP is 0.47 which is maximum value shown in this heatmap. Likewise, correlation value between ASTV and NSP is also 0.47. Hence, they have positive correlation (both variable varies in same direction)
#
# any value < 0.1 is considered as no-correlation. Therefore, variables like FM, DL have no correlation with NSP. Remaining variables either have negative correlation or very less correlation with NSP (Negative correlation means both variable varies in opposite direction)

# %% [markdown]
# #Employ advanced visualization techniques like pair plots, or violin plots for deeper insights.

# %%
sns.violinplot(x=data1['LB'])  # it will show the distribution of data inside column LB using violinplot func.
# Out:
# <Axes: xlabel='LB'>

# %%
sns.violinplot(x = data1['AC']) # it will show the distribution of data inside column AC using violinplot func.
# Out:
# <Axes: xlabel='AC'>

# %%
sns.violinplot(x = data1['FM']) # it will show the distribution of data inside this column using violinplot func.
# Out:
# <Axes: xlabel='FM'>

# %%
sns.violinplot(x = data1['UC']) # it will show the distribution of data inside this column using violinplot func.
# Out:
# <Axes: xlabel='UC'>

# %%
sns.violinplot(x = data1['DL']) # it will show the distribution of data inside this column using violinplot func.
# Out:
# <Axes: xlabel='DL'>

# %%
sns.violinplot(x = data1['DS']) # it will show the distribution of data inside this column using violinplot func.
# Out:
# <Axes: xlabel='DS'>

# %%
sns.violinplot(x=data1['DP'])
# Out:
# <Axes: xlabel='DP'>

# %%
sns.violinplot(x = data1['ASTV']) # it will show the distribution of data inside this column using violinplot func.
# Out:
# <Axes: xlabel='ASTV'>

# %%
sns.violinplot(x = data1['MSTV'])
# Out:
# <Axes: xlabel='MSTV'>

# %%
sns.violinplot(x = data1['ALTV'])
# Out:
# <Axes: xlabel='ALTV'>

# %%
sns.violinplot(x = data1['MLTV'])
# Out:
# <Axes: xlabel='MLTV'>

# %%
sns.violinplot(x = data1['Width']) # it will show the distribution of data inside this column using violinplot func.
# Out:
# <Axes: xlabel='Width'>

# %%
sns.violinplot(x = data1['Tendency']) # it will show the distribution of data
# Out:
# <Axes: xlabel='Tendency'>

# %%
sns.violinplot(x = data1['NSP']) # it will show the distribution of data
# Out:
# <Axes: xlabel='NSP'>

# %% [markdown]
# #4 Pattern Recognition and insights:
#
# Identify any correlations between variables and discuss their potential implications: already explained above using heatmap and scatter plot
#
# Look for trends or patterns over time if temporal data is available: for getting the insights of trend or pattern, the dataset must be time series where date column is compulsory. Since, our dataset does not meet the condition, so, we can not give insight of trends here.
#
# But we can draw the plot between variable LB and NSP to see the slope which is very helpful in determining the trend.
#
# Likewise, we can check the slope between other variables as well but this is only meaningful with respect to date column.

# %%
sns.lineplot(x=data1['LB'], y=data1['NSP'],label='pattern', color='blue')
 
# Adding labels and title
plt.xlabel('LB')
plt.ylabel('NSP')
plt.title('checking trend')
# Out:
# Text(0.5, 1.0, 'checking trend')

# %% [markdown]
# if the slope is a +ve value Then increasing trend
# if the slope value is neative then decreasing trend
# if the slope is a zero vlaue then no trend

# %% [markdown]
# #Conclusion
#
# A machine learning algorithm can not run if there are missing values, outliers in the dataset. We can treat missing values using Imputation technique. Imputation technique is used for replacing the missing data with some substitute values to retain most of the data/information of the dataset. These substitute values can be either mean, median or mode. After treating missing values, our next goal is to remove the outliers and for it, outlier detection is needed which is done by boxplot. Once we remove outliers, our data becomes normal distributed i.e. symmetrical about the mean and now, we are in the position to train our machine learning model successfully. Through IQR, we will understand how middle 50% data is spread and heatmap will help us to understand whether our variables have good correlation or not which ultimately helps us in getting close to the future predictions especially when we are working on Time Series data
